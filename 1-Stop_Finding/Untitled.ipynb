# %%
import pickle

print('Reading file...')
with open('../data/yg_tripdata_2016-05.pickle', 'rb') as f:
    nyc_taxi = pickle.load(f)
# Out:
# Reading file...

# %%
nyc_taxi.head()
# Out:
#    VendorID pickup_datetime    dropoff_datetime  pickup_longitude  \
# 0         1      2016-05-01 2016-05-01 00:17:31        -73.985901
# 1         2      2016-05-01 2016-05-01 00:07:31        -73.991577
# 2         2      2016-05-01 2016-05-01 00:07:01        -73.993073
# 3         2      2016-05-01 2016-05-01 00:19:47        -73.991943
# 4         2      2016-05-01 2016-05-01 00:06:39        -74.005280
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  trip_distance  \
# 0        40.768040         -73.983986         40.730099           3.60
# 1        40.744751         -73.975700         40.765469           1.68
# 2        40.741573         -73.980995         40.744633           1.09
# 3        40.684601         -74.002258         40.733002           4.21
# 4        40.740192         -73.997498         40.737564           0.56
#
#    total_amount    type  drop_day  drop_hour  pick_day  pick_hour  \
# 0         17.80  yellow         1          0         1          0
# ...
