# %%
import pandas as pd
import numpy as np

# %%
chicago_df = pd.read_csv('../data/chicago_18_month_data.csv')

# %%
chicago_df.iloc[5000:5010]
# Out:
#       Unnamed: 0                            company  dropoff_census_tract  \
# 5000        5000                                NaN          1.703132e+10
# 5001        5001                                NaN          1.703132e+10
# 5002        5002                                NaN                   NaN
# 5003        5003                                NaN                   NaN
# 5004        5004          Taxi Affiliation Services          1.703181e+10
# 5005        5005                                NaN          1.703108e+10
# 5006        5006                                NaN                   NaN
# 5007        5007                Top Cab Affiliation                   NaN
# 5008        5008  Blue Ribbon Taxi Association Inc.                   NaN
# 5009        5009           Northwest Management LLC                   NaN
#
#       dropoff_centroid_latitude  \
# 5000                  41.877406
# 5001                  41.877406
# 5002                  41.878866
# ...

# %%
latlon = chicago_df[['dropoff_centroid_latitude', 'dropoff_centroid_longitude']]
latlon = latlon.dropna()
uniq_latlon, cnts = np.unique(latlon, axis=0, return_counts=True)

# %%
len(chicago_df), len(uniq_latlon), cnts
# Out:
# (1092557,
#  377,
#  array([     3,     14,     43,     71,     84,     42,     24,    107,
#             17,    156,     68,      5,     71,      1,    231,    132,
#             70,    112,    302,      3,      2,      4,    466,      1,
#            199,    131,     95,    102,      3,    143,    521,    172,
#              1,   9985,      3,    216,    299,     26,    184,   2729,
#             81,   4098,      5,     87,     13,     23,      4,      1,
#              2,     34,   1330,    315,     87,    146,    651,    219,
#             18,    340,     60,     22,    820,      5,    418,     93,
#              5,      2,   2200,   1337,    461,      1,      3,     31,
#             13,   1982,      4,  13645,   2584,    556,      3,      9,
#              5,     41,   4976,  25444,    342,    334,    303,     13,
#           4138,     34,     27,   1005,  14771,   3744,      4,     56,
#          18289,     44,      8,  23172,    111,    773,  18821,    466,
# ...

# %%
nyc_df_yellow = pd.read_csv('../data/yellow_tripdata_2017-06.csv')

# %%
nyc_df_yellow.iloc[5000:5010]
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 5000         1  2017-06-09 18:28:32   2017-06-09 18:52:53                1
# 5001         1  2017-06-09 18:28:33   2017-06-09 18:41:55                1
# 5002         1  2017-06-09 18:28:33   2017-06-09 18:51:34                2
# 5003         1  2017-06-09 18:28:34   2017-06-09 18:33:45                1
# 5004         1  2017-06-09 18:28:35   2017-06-09 18:50:37                1
# 5005         1  2017-06-09 18:28:35   2017-06-09 18:43:39                4
# 5006         1  2017-06-09 18:28:35   2017-06-09 18:33:49                1
# 5007         1  2017-06-09 18:28:36   2017-06-09 18:34:23                1
# 5008         1  2017-06-09 18:28:36   2017-06-09 19:00:42                1
# 5009         1  2017-06-09 18:28:37   2017-06-09 18:42:51                1
#
#       trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 5000            3.3           1                  N           255
# ...

# %%
len(nyc_df_yellow)
# Out:
# 9656993

# %%
nyc_df_green = pd.read_csv('../data/green_tripdata_2017-06.csv')

# %%
nyc_df_green.iloc[5000:5010]
# Out:
#       VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 5000         2  2017-06-01 08:44:30   2017-06-01 08:53:32                  N
# 5001         2  2017-06-01 08:43:00   2017-06-01 08:53:41                  N
# 5002         2  2017-06-01 08:43:42   2017-06-01 08:53:44                  N
# 5003         2  2017-06-01 08:43:05   2017-06-01 08:53:37                  N
# 5004         2  2017-06-01 08:38:05   2017-06-01 08:52:30                  N
# 5005         2  2017-06-01 08:40:11   2017-06-01 08:53:49                  N
# 5006         2  2017-06-01 08:46:27   2017-06-01 08:53:47                  N
# 5007         2  2017-06-01 08:40:21   2017-06-01 08:52:20                  N
# 5008         2  2017-06-01 08:48:29   2017-06-01 08:53:51                  N
# 5009         2  2017-06-01 08:38:13   2017-06-01 08:53:38                  N
#
#       RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# ...

# %%
len(nyc_df_green)
# Out:
# 976467

# %%
nyc_df_fhv = pd.read_csv('../data/fhv_tripdata_2017-06.csv')

# %%
nyc_df_fhv.iloc[5000:5010]
# Out:
#      Dispatching_base_num      Pickup_DateTime     DropOff_datetime  \
# 5000               B02682  2017-06-01 00:42:59  2017-06-01 00:45:36
# 5001               B02682  2017-06-01 00:50:09  2017-06-01 00:55:18
# 5002               B02682  2017-06-01 00:13:22  2017-06-01 00:17:30
# 5003               B02682  2017-06-01 00:42:20  2017-06-01 00:49:31
# 5004               B02682  2017-06-01 00:16:13  2017-06-01 00:27:15
# 5005               B02682  2017-06-01 00:44:07  2017-06-01 00:48:59
# 5006               B02682  2017-06-01 00:14:18  2017-06-01 00:26:17
# 5007               B02682  2017-06-01 00:37:23  2017-06-01 00:43:55
# 5008               B02682  2017-06-01 00:56:25  2017-06-01 01:37:46
# 5009               B02682  2017-06-01 00:20:09  2017-06-01 00:54:20
#
#       PUlocationID  DOlocationID
# 5000         182.0         182.0
# 5001         182.0         182.0
# 5002         259.0         259.0
# 5003         182.0         254.0
# 5004         231.0         233.0
# ...

# %%
len(nyc_df_fhv)
# Out:
# 15362154

# %%
nyc_df_fhv['count'] = 1
nyc_df_fhv[['Dispatching_base_num', 'count']].groupby('Dispatching_base_num').sum().sort_values('count', ascending=False)
# Out:
#                         count
# Dispatching_base_num
# B02510                2011492
# B02764                1365098
# B02800                 786935
# B02682                 763279
# B02914                 627672
# B02882                 569418
# B02884                 553791
# B02876                 522878
# B02867                 461592
# B02888                 451146
# B02835                 409034
# B02877                 319224
# B02907                 284732
# B02880                 281537
# B02836                 278943
# B02889                 277782
# B02866                 259393
# B02878                 225150
# B02864                 211832
# B02870                 204397
# B02865                 204127
# B02617                 189365
# B02395                 187816
# B02765                 184981
# B02879                 176585
# B02869                 152345
# B02872                 146111
# B02887                 145079
# B02883                 116650
# ...

# %%
fhv_df = pd.read_csv('../data/fhv_bases.csv')

# %%
fhv_df
# Out:
#     base_number                                      base_name  \
# 0        B00001                            LONDON TOWNCARS INC
# 1        B00008                           T-D MAINTENANCE CORP
# 2        B00009                                T-D MAINTENANCE
# 3        B00013                         LOVE CORPORATE CAR INC
# 4        B00014                            NY ONE CORP CAR INC
# 5        B00021                       MEXICANA HIGH CLASS INC.
# 6        B00029                         COMMUNITY CAR SVC CORP
# 7        B00030                       TREMONT DISPATCHING CORP
# 8        B00031                            QUEENS VILLAGE INC.
# 9        B00035                                 LOTUS RIDE INC
# 10       B00037                           TRANSP UNLIMITED C/S
# 11       B00039                 BERMUDA LIMOUSINE SERVICE INC.
# 12       B00053                            CHARGE AND RIDE INC
# 13       B00054                   128 BLUE BIRD TRANSPORT INC.
# ...

# %%
fhv_df[['dba_category']].groupby('dba_category').sum()
# Out:
# Empty DataFrame
# Columns: []
# Index: [juno, lyft, other, uber, via]

# %%
nyc_fhv_full = nyc_df_fhv.set_index('Dispatching_base_num').join(fhv_df[['base_number', 'dba_category']].set_index('base_number'))

# %%
nyc_fhv_full
# Out:
#             Pickup_DateTime     DropOff_datetime  PUlocationID  DOlocationID  \
# B00001  2017-06-01 00:04:00  2017-06-07 01:55:36           NaN           NaN
# B00001  2017-06-01 00:47:00  2017-06-09 01:25:40           NaN           NaN
# B00001  2017-06-01 00:07:00  2017-06-15 00:52:17           NaN           NaN
# B00001  2017-06-01 00:30:00  2017-06-03 02:18:52           NaN           NaN
# B00001  2017-06-01 00:45:00  2017-06-10 01:49:42           NaN           NaN
# B00001  2017-06-01 00:25:00  2017-06-19 00:58:48           NaN           NaN
# B00001  2017-06-01 01:00:00  2017-06-09 02:20:16           NaN           NaN
# B00001  2017-06-01 01:23:00  2017-06-14 02:34:05           NaN           NaN
# B00001  2017-06-01 02:06:00  2017-06-09 02:56:52           NaN           NaN
# B00001  2017-06-01 03:15:00  2017-06-27 03:53:01           NaN           NaN
# B00001  2017-06-01 04:00:00  2017-06-21 04:29:07           NaN           NaN
# ...
